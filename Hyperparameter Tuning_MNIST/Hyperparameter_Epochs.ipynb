# %%
import numpy as np 
import struct
from array import array
import os
import random
import matplotlib.pyplot as plt
from mlp import MultilayerPerceptron, Layer, CrossEntropy, Relu, Softmax

# -------------------- MNIST Data Loader Class -------------------- #

class MnistDataloader(object):
    """
    A class to load and preprocess the MNIST dataset from IDX files.
    """
    def __init__(self, training_images_filepath, training_labels_filepath,
                 test_images_filepath, test_labels_filepath):
        self.training_images_filepath = training_images_filepath
        self.training_labels_filepath = training_labels_filepath
        self.test_images_filepath = test_images_filepath
        self.test_labels_filepath = test_labels_filepath
    
    def read_images_labels(self, images_filepath, labels_filepath):        
        """
        Reads image and label data from IDX files.
        """
        # Read labels
        labels = []
        with open(labels_filepath, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))  # Read magic number and size
            if magic != 2049:
                raise ValueError(f'Magic number mismatch, expected 2049, got {magic}')
            labels = array("B", file.read())        
        
        # Read images
        with open(images_filepath, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))  # Read metadata
            if magic != 2051:
                raise ValueError(f'Magic number mismatch, expected 2051, got {magic}')
            image_data = array("B", file.read())  # Read pixel data        
        
        # Reshape image data into (size, 28, 28)
        images = [np.array(image_data[i * rows * cols:(i + 1) * rows * cols]).reshape(28, 28) for i in range(size)]
        
        return images, labels
            
    def load_data(self):
        """
        Loads training and test datasets.
        """
        x_train, y_train = self.read_images_labels(self.training_images_filepath, self.training_labels_filepath)
        x_test, y_test = self.read_images_labels(self.test_images_filepath, self.test_labels_filepath)
        return (x_train, y_train), (x_test, y_test)  

# -------------------- Reading Dataset via MnistDataloader class -------------------- #

data_folder = 'MNIST-data/'  # Dataset directory

# File paths for MNIST dataset
training_images_filepath = os.path.join(data_folder, 'train-images.idx3-ubyte')
training_labels_filepath = os.path.join(data_folder, 'train-labels.idx1-ubyte')
test_images_filepath = os.path.join(data_folder, 't10k-images.idx3-ubyte')
test_labels_filepath = os.path.join(data_folder, 't10k-labels.idx1-ubyte')

# Loading MNIST dataset
mnist_dataloader = MnistDataloader(training_images_filepath, training_labels_filepath, test_images_filepath, test_labels_filepath)
(x_train, y_train), (x_test, y_test) = mnist_dataloader.load_data()

# Converting lists to NumPy arrays and normalize pixel values
x_train = np.array(x_train).reshape(-1, 784) / 255.0  # Normalize & flatten
x_test = np.array(x_test).reshape(-1, 784) / 255.0
y_train = np.array(y_train)
y_test = np.array(y_test)

# Manual Train-Validation Split (80% train, 20% validation)
split_idx = int(len(x_train) * 0.8)
x_train, x_val = x_train[:split_idx], x_train[split_idx:]
y_train, y_val = y_train[:split_idx], y_train[split_idx:]

# Function to one-hot encode labels
def one_hot_encode(labels, num_classes=10):
    one_hot = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        one_hot[i][label] = 1
    return one_hot

# Converting labels to one-hot encoding
y_train = one_hot_encode(y_train)
y_val = one_hot_encode(y_val)
y_test = one_hot_encode(y_test)

# Function to display sample images
def show_images(images, title_texts):
    cols = 5
    rows = int(len(images) / cols) + 1
    plt.figure(figsize=(30, 20))
    index = 1
    for img, title in zip(images, title_texts):
        plt.subplot(rows, cols, index)
        plt.imshow(img, cmap=plt.cm.gray)
        plt.title(title, fontsize=15)
        index += 1

# -------------------- MLP Architecture for MNIST Dataset -------------------- #

# Define different epoch values to test
epoch_values = [10, 20, 50, 100, 200]

# Fixed layer architecture for comparison
fixed_layers = [
    Layer(784, 128, Relu(), dropout_rate=0.0),
    Layer(128, 128, Relu(), dropout_rate=0.0),
    Layer(128, 10, Softmax())
]

# Store results of test accuracies
results = {}

# Loop through different epoch values
for idx, epochs in enumerate(epoch_values):
    print(f"\nTraining with {epochs} Epochs")

    # Define the MLP model with fixed layers
    mlp = MultilayerPerceptron(fixed_layers)

    # Define loss function
    loss_function = CrossEntropy()

    # Train the model
    train_losses, val_losses = mlp.train(
        x_train, y_train, x_val, y_val,
        loss_function, learning_rate=0.001,  # Keeping learning rate constant
        batch_size=64, epochs=epochs, optimizer='vanilla', momentum=0.7  # Keeping momentum constant
    )

    # Evaluating model on test set
    y_pred = mlp.forward(x_test)
    test_accuracy = np.mean(np.argmax(y_pred, axis=1) == np.argmax(y_test, axis=1))

    # Store the result
    results[idx] = {
        "epochs": epochs,
        "test_accuracy": test_accuracy
    }

    print(f"Epochs {epochs}: Test Accuracy: {test_accuracy * 100:.2f}%")

# Find the best epoch value based on test accuracy
best_epoch_idx = max(results, key=lambda x: results[x]["test_accuracy"])
best_epoch = results[best_epoch_idx]

print("\nBest Epoch Configuration:")
print(f"Epochs: {best_epoch['epochs']}")
print(f"Test Accuracy: {best_epoch['test_accuracy'] * 100:.2f}%")
# Out:
# Training with 10 Epochs
# Epoch 1/10 - Train Loss: 0.3045, Val Loss: 0.1739
# Epoch 2/10 - Train Loss: 0.1273, Val Loss: 0.1185
# Epoch 3/10 - Train Loss: 0.0887, Val Loss: 0.1203
# Epoch 4/10 - Train Loss: 0.0665, Val Loss: 0.1027
# Epoch 5/10 - Train Loss: 0.0515, Val Loss: 0.0925
# Epoch 6/10 - Train Loss: 0.0402, Val Loss: 0.0900
# Epoch 7/10 - Train Loss: 0.0317, Val Loss: 0.0988
# Epoch 8/10 - Train Loss: 0.0263, Val Loss: 0.1004
# Epoch 9/10 - Train Loss: 0.0196, Val Loss: 0.0918
# Epoch 10/10 - Train Loss: 0.0161, Val Loss: 0.1014
# Epochs 10: Test Accuracy: 97.52%
#
# Training with 20 Epochs
# Epoch 1/20 - Train Loss: 0.0130, Val Loss: 0.0910
# Epoch 2/20 - Train Loss: 0.0086, Val Loss: 0.0861
# Epoch 3/20 - Train Loss: 0.0064, Val Loss: 0.0873
# Epoch 4/20 - Train Loss: 0.0038, Val Loss: 0.0878
# Epoch 5/20 - Train Loss: 0.0022, Val Loss: 0.0891
# Epoch 6/20 - Train Loss: 0.0015, Val Loss: 0.0900
# Epoch 7/20 - Train Loss: 0.0012, Val Loss: 0.0928
# Epoch 8/20 - Train Loss: 0.0010, Val Loss: 0.0930
# Epoch 9/20 - Train Loss: 0.0008, Val Loss: 0.0933
# Epoch 10/20 - Train Loss: 0.0007, Val Loss: 0.0946
# Epoch 11/20 - Train Loss: 0.0006, Val Loss: 0.0958
# Epoch 12/20 - Train Loss: 0.0006, Val Loss: 0.0958
# Epoch 13/20 - Train Loss: 0.0006, Val Loss: 0.0960
# Epoch 14/20 - Train Loss: 0.0005, Val Loss: 0.0972
# Epoch 15/20 - Train Loss: 0.0005, Val Loss: 0.0979
# Epoch 16/20 - Train Loss: 0.0004, Val Loss: 0.0978
# Epoch 17/20 - Train Loss: 0.0004, Val Loss: 0.0991
# Epoch 18/20 - Train Loss: 0.0004, Val Loss: 0.0989
# Epoch 19/20 - Train Loss: 0.0004, Val Loss: 0.0991
# Epoch 20/20 - Train Loss: 0.0004, Val Loss: 0.0998
# Epochs 20: Test Accuracy: 98.06%
#
# Training with 50 Epochs
# Epoch 1/50 - Train Loss: 0.0003, Val Loss: 0.1001
# Epoch 2/50 - Train Loss: 0.0003, Val Loss: 0.1005
# Epoch 3/50 - Train Loss: 0.0003, Val Loss: 0.1009
# Epoch 4/50 - Train Loss: 0.0003, Val Loss: 0.1014
# Epoch 5/50 - Train Loss: 0.0003, Val Loss: 0.1019
# Epoch 6/50 - Train Loss: 0.0003, Val Loss: 0.1024
# Epoch 7/50 - Train Loss: 0.0003, Val Loss: 0.1026
# Epoch 8/50 - Train Loss: 0.0002, Val Loss: 0.1030
# Epoch 9/50 - Train Loss: 0.0002, Val Loss: 0.1036
# Epoch 10/50 - Train Loss: 0.0002, Val Loss: 0.1038
# Epoch 11/50 - Train Loss: 0.0002, Val Loss: 0.1040
# Epoch 12/50 - Train Loss: 0.0002, Val Loss: 0.1041
# Epoch 13/50 - Train Loss: 0.0002, Val Loss: 0.1044
# Epoch 14/50 - Train Loss: 0.0002, Val Loss: 0.1049
# Epoch 15/50 - Train Loss: 0.0002, Val Loss: 0.1052
# Epoch 16/50 - Train Loss: 0.0002, Val Loss: 0.1054
# Epoch 17/50 - Train Loss: 0.0002, Val Loss: 0.1056
# Epoch 18/50 - Train Loss: 0.0002, Val Loss: 0.1059
# Epoch 19/50 - Train Loss: 0.0002, Val Loss: 0.1059
# Epoch 20/50 - Train Loss: 0.0002, Val Loss: 0.1064
# Epoch 21/50 - Train Loss: 0.0002, Val Loss: 0.1065
# Epoch 22/50 - Train Loss: 0.0002, Val Loss: 0.1068
# Epoch 23/50 - Train Loss: 0.0002, Val Loss: 0.1071
# Epoch 24/50 - Train Loss: 0.0002, Val Loss: 0.1075
# Epoch 25/50 - Train Loss: 0.0002, Val Loss: 0.1077
# Epoch 26/50 - Train Loss: 0.0001, Val Loss: 0.1079
# Epoch 27/50 - Train Loss: 0.0001, Val Loss: 0.1079
# Epoch 28/50 - Train Loss: 0.0001, Val Loss: 0.1084
# Epoch 29/50 - Train Loss: 0.0001, Val Loss: 0.1085
# Epoch 30/50 - Train Loss: 0.0001, Val Loss: 0.1089
# Epoch 31/50 - Train Loss: 0.0001, Val Loss: 0.1089
# Epoch 32/50 - Train Loss: 0.0001, Val Loss: 0.1092
# Epoch 33/50 - Train Loss: 0.0001, Val Loss: 0.1095
# Epoch 34/50 - Train Loss: 0.0001, Val Loss: 0.1095
# Epoch 35/50 - Train Loss: 0.0001, Val Loss: 0.1097
# Epoch 36/50 - Train Loss: 0.0001, Val Loss: 0.1101
# Epoch 37/50 - Train Loss: 0.0001, Val Loss: 0.1101
# Epoch 38/50 - Train Loss: 0.0001, Val Loss: 0.1103
# Epoch 39/50 - Train Loss: 0.0001, Val Loss: 0.1106
# Epoch 40/50 - Train Loss: 0.0001, Val Loss: 0.1106
# Epoch 41/50 - Train Loss: 0.0001, Val Loss: 0.1108
# Epoch 42/50 - Train Loss: 0.0001, Val Loss: 0.1109
# Epoch 43/50 - Train Loss: 0.0001, Val Loss: 0.1113
# Epoch 44/50 - Train Loss: 0.0001, Val Loss: 0.1112
# Epoch 45/50 - Train Loss: 0.0001, Val Loss: 0.1115
# Epoch 46/50 - Train Loss: 0.0001, Val Loss: 0.1116
# Epoch 47/50 - Train Loss: 0.0001, Val Loss: 0.1117
# Epoch 48/50 - Train Loss: 0.0001, Val Loss: 0.1120
# Epoch 49/50 - Train Loss: 0.0001, Val Loss: 0.1120
# Epoch 50/50 - Train Loss: 0.0001, Val Loss: 0.1123
# Epochs 50: Test Accuracy: 98.03%
#
# Training with 100 Epochs
# Epoch 1/100 - Train Loss: 0.0001, Val Loss: 0.1123
# Epoch 2/100 - Train Loss: 0.0001, Val Loss: 0.1125
# Epoch 3/100 - Train Loss: 0.0001, Val Loss: 0.1125
# Epoch 4/100 - Train Loss: 0.0001, Val Loss: 0.1127
# Epoch 5/100 - Train Loss: 0.0001, Val Loss: 0.1130
# Epoch 6/100 - Train Loss: 0.0001, Val Loss: 0.1131
# Epoch 7/100 - Train Loss: 0.0001, Val Loss: 0.1133
# Epoch 8/100 - Train Loss: 0.0001, Val Loss: 0.1133
# Epoch 9/100 - Train Loss: 0.0001, Val Loss: 0.1135
# Epoch 10/100 - Train Loss: 0.0001, Val Loss: 0.1135
# Epoch 11/100 - Train Loss: 0.0001, Val Loss: 0.1137
# Epoch 12/100 - Train Loss: 0.0001, Val Loss: 0.1139
# Epoch 13/100 - Train Loss: 0.0001, Val Loss: 0.1140
# Epoch 14/100 - Train Loss: 0.0001, Val Loss: 0.1142
# Epoch 15/100 - Train Loss: 0.0001, Val Loss: 0.1143
# Epoch 16/100 - Train Loss: 0.0001, Val Loss: 0.1142
# Epoch 17/100 - Train Loss: 0.0001, Val Loss: 0.1145
# Epoch 18/100 - Train Loss: 0.0001, Val Loss: 0.1147
# Epoch 19/100 - Train Loss: 0.0001, Val Loss: 0.1149
# Epoch 20/100 - Train Loss: 0.0001, Val Loss: 0.1149
# Epoch 21/100 - Train Loss: 0.0001, Val Loss: 0.1148
# Epoch 22/100 - Train Loss: 0.0001, Val Loss: 0.1150
# Epoch 23/100 - Train Loss: 0.0001, Val Loss: 0.1151
# Epoch 24/100 - Train Loss: 0.0001, Val Loss: 0.1152
# Epoch 25/100 - Train Loss: 0.0001, Val Loss: 0.1153
# Epoch 26/100 - Train Loss: 0.0001, Val Loss: 0.1156
# Epoch 27/100 - Train Loss: 0.0001, Val Loss: 0.1157
# Epoch 28/100 - Train Loss: 0.0001, Val Loss: 0.1156
# Epoch 29/100 - Train Loss: 0.0001, Val Loss: 0.1158
# Epoch 30/100 - Train Loss: 0.0001, Val Loss: 0.1159
# Epoch 31/100 - Train Loss: 0.0001, Val Loss: 0.1160
# Epoch 32/100 - Train Loss: 0.0001, Val Loss: 0.1160
# Epoch 33/100 - Train Loss: 0.0001, Val Loss: 0.1163
# Epoch 34/100 - Train Loss: 0.0001, Val Loss: 0.1163
# Epoch 35/100 - Train Loss: 0.0001, Val Loss: 0.1163
# Epoch 36/100 - Train Loss: 0.0001, Val Loss: 0.1166
# Epoch 37/100 - Train Loss: 0.0001, Val Loss: 0.1166
# Epoch 38/100 - Train Loss: 0.0001, Val Loss: 0.1167
# Epoch 39/100 - Train Loss: 0.0001, Val Loss: 0.1169
# Epoch 40/100 - Train Loss: 0.0001, Val Loss: 0.1170
# Epoch 41/100 - Train Loss: 0.0001, Val Loss: 0.1169
# Epoch 42/100 - Train Loss: 0.0001, Val Loss: 0.1171
# Epoch 43/100 - Train Loss: 0.0001, Val Loss: 0.1172
# Epoch 44/100 - Train Loss: 0.0001, Val Loss: 0.1173
# Epoch 45/100 - Train Loss: 0.0001, Val Loss: 0.1174
# Epoch 46/100 - Train Loss: 0.0001, Val Loss: 0.1174
# Epoch 47/100 - Train Loss: 0.0001, Val Loss: 0.1177
# Epoch 48/100 - Train Loss: 0.0001, Val Loss: 0.1177
# Epoch 49/100 - Train Loss: 0.0001, Val Loss: 0.1178
# Epoch 50/100 - Train Loss: 0.0001, Val Loss: 0.1178
# Epoch 51/100 - Train Loss: 0.0001, Val Loss: 0.1179
# Epoch 52/100 - Train Loss: 0.0000, Val Loss: 0.1180
# Epoch 53/100 - Train Loss: 0.0000, Val Loss: 0.1182
# Epoch 54/100 - Train Loss: 0.0000, Val Loss: 0.1181
# Epoch 55/100 - Train Loss: 0.0000, Val Loss: 0.1182
# Epoch 56/100 - Train Loss: 0.0000, Val Loss: 0.1183
# Epoch 57/100 - Train Loss: 0.0000, Val Loss: 0.1185
# Epoch 58/100 - Train Loss: 0.0000, Val Loss: 0.1186
# Epoch 59/100 - Train Loss: 0.0000, Val Loss: 0.1186
# Epoch 60/100 - Train Loss: 0.0000, Val Loss: 0.1187
# Epoch 61/100 - Train Loss: 0.0000, Val Loss: 0.1187
# Epoch 62/100 - Train Loss: 0.0000, Val Loss: 0.1188
# Epoch 63/100 - Train Loss: 0.0000, Val Loss: 0.1189
# Epoch 64/100 - Train Loss: 0.0000, Val Loss: 0.1191
# Epoch 65/100 - Train Loss: 0.0000, Val Loss: 0.1190
# Epoch 66/100 - Train Loss: 0.0000, Val Loss: 0.1192
# Epoch 67/100 - Train Loss: 0.0000, Val Loss: 0.1192
# Epoch 68/100 - Train Loss: 0.0000, Val Loss: 0.1193
# Epoch 69/100 - Train Loss: 0.0000, Val Loss: 0.1195
# Epoch 70/100 - Train Loss: 0.0000, Val Loss: 0.1194
# Epoch 71/100 - Train Loss: 0.0000, Val Loss: 0.1196
# Epoch 72/100 - Train Loss: 0.0000, Val Loss: 0.1196
# Epoch 73/100 - Train Loss: 0.0000, Val Loss: 0.1198
# Epoch 74/100 - Train Loss: 0.0000, Val Loss: 0.1198
# Epoch 75/100 - Train Loss: 0.0000, Val Loss: 0.1199
# Epoch 76/100 - Train Loss: 0.0000, Val Loss: 0.1199
# Epoch 77/100 - Train Loss: 0.0000, Val Loss: 0.1200
# Epoch 78/100 - Train Loss: 0.0000, Val Loss: 0.1200
# Epoch 79/100 - Train Loss: 0.0000, Val Loss: 0.1201
# Epoch 80/100 - Train Loss: 0.0000, Val Loss: 0.1203
# Epoch 81/100 - Train Loss: 0.0000, Val Loss: 0.1204
# Epoch 82/100 - Train Loss: 0.0000, Val Loss: 0.1204
# Epoch 83/100 - Train Loss: 0.0000, Val Loss: 0.1204
# Epoch 84/100 - Train Loss: 0.0000, Val Loss: 0.1206
# Epoch 85/100 - Train Loss: 0.0000, Val Loss: 0.1206
# Epoch 86/100 - Train Loss: 0.0000, Val Loss: 0.1206
# Epoch 87/100 - Train Loss: 0.0000, Val Loss: 0.1207
# Epoch 88/100 - Train Loss: 0.0000, Val Loss: 0.1208
# Epoch 89/100 - Train Loss: 0.0000, Val Loss: 0.1208
# Epoch 90/100 - Train Loss: 0.0000, Val Loss: 0.1209
# Epoch 91/100 - Train Loss: 0.0000, Val Loss: 0.1210
# Epoch 92/100 - Train Loss: 0.0000, Val Loss: 0.1211
# Epoch 93/100 - Train Loss: 0.0000, Val Loss: 0.1211
# Epoch 94/100 - Train Loss: 0.0000, Val Loss: 0.1213
# Epoch 95/100 - Train Loss: 0.0000, Val Loss: 0.1213
# Epoch 96/100 - Train Loss: 0.0000, Val Loss: 0.1214
# Epoch 97/100 - Train Loss: 0.0000, Val Loss: 0.1213
# Epoch 98/100 - Train Loss: 0.0000, Val Loss: 0.1215
# Epoch 99/100 - Train Loss: 0.0000, Val Loss: 0.1215
# Epoch 100/100 - Train Loss: 0.0000, Val Loss: 0.1215
# Epochs 100: Test Accuracy: 98.06%
#
# Training with 200 Epochs
# Epoch 1/200 - Train Loss: 0.0000, Val Loss: 0.1216
# Epoch 2/200 - Train Loss: 0.0000, Val Loss: 0.1216
# Epoch 3/200 - Train Loss: 0.0000, Val Loss: 0.1218
# Epoch 4/200 - Train Loss: 0.0000, Val Loss: 0.1218
# Epoch 5/200 - Train Loss: 0.0000, Val Loss: 0.1218
# Epoch 6/200 - Train Loss: 0.0000, Val Loss: 0.1220
# Epoch 7/200 - Train Loss: 0.0000, Val Loss: 0.1220
# Epoch 8/200 - Train Loss: 0.0000, Val Loss: 0.1221
# Epoch 9/200 - Train Loss: 0.0000, Val Loss: 0.1223
# Epoch 10/200 - Train Loss: 0.0000, Val Loss: 0.1222
# Epoch 11/200 - Train Loss: 0.0000, Val Loss: 0.1223
# Epoch 12/200 - Train Loss: 0.0000, Val Loss: 0.1223
# Epoch 13/200 - Train Loss: 0.0000, Val Loss: 0.1223
# Epoch 14/200 - Train Loss: 0.0000, Val Loss: 0.1225
# Epoch 15/200 - Train Loss: 0.0000, Val Loss: 0.1225
# Epoch 16/200 - Train Loss: 0.0000, Val Loss: 0.1226
# Epoch 17/200 - Train Loss: 0.0000, Val Loss: 0.1226
# Epoch 18/200 - Train Loss: 0.0000, Val Loss: 0.1226
# Epoch 19/200 - Train Loss: 0.0000, Val Loss: 0.1227
# Epoch 20/200 - Train Loss: 0.0000, Val Loss: 0.1228
# Epoch 21/200 - Train Loss: 0.0000, Val Loss: 0.1229
# Epoch 22/200 - Train Loss: 0.0000, Val Loss: 0.1229
# Epoch 23/200 - Train Loss: 0.0000, Val Loss: 0.1230
# Epoch 24/200 - Train Loss: 0.0000, Val Loss: 0.1231
# Epoch 25/200 - Train Loss: 0.0000, Val Loss: 0.1231
# Epoch 26/200 - Train Loss: 0.0000, Val Loss: 0.1232
# Epoch 27/200 - Train Loss: 0.0000, Val Loss: 0.1232
# Epoch 28/200 - Train Loss: 0.0000, Val Loss: 0.1233
# Epoch 29/200 - Train Loss: 0.0000, Val Loss: 0.1233
# Epoch 30/200 - Train Loss: 0.0000, Val Loss: 0.1233
# Epoch 31/200 - Train Loss: 0.0000, Val Loss: 0.1235
# Epoch 32/200 - Train Loss: 0.0000, Val Loss: 0.1235
# Epoch 33/200 - Train Loss: 0.0000, Val Loss: 0.1235
# Epoch 34/200 - Train Loss: 0.0000, Val Loss: 0.1236
# Epoch 35/200 - Train Loss: 0.0000, Val Loss: 0.1237
# Epoch 36/200 - Train Loss: 0.0000, Val Loss: 0.1237
# Epoch 37/200 - Train Loss: 0.0000, Val Loss: 0.1237
# Epoch 38/200 - Train Loss: 0.0000, Val Loss: 0.1238
# Epoch 39/200 - Train Loss: 0.0000, Val Loss: 0.1238
# Epoch 40/200 - Train Loss: 0.0000, Val Loss: 0.1239
# Epoch 41/200 - Train Loss: 0.0000, Val Loss: 0.1240
# Epoch 42/200 - Train Loss: 0.0000, Val Loss: 0.1240
# Epoch 43/200 - Train Loss: 0.0000, Val Loss: 0.1241
# Epoch 44/200 - Train Loss: 0.0000, Val Loss: 0.1241
# Epoch 45/200 - Train Loss: 0.0000, Val Loss: 0.1242
# Epoch 46/200 - Train Loss: 0.0000, Val Loss: 0.1242
# Epoch 47/200 - Train Loss: 0.0000, Val Loss: 0.1242
# Epoch 48/200 - Train Loss: 0.0000, Val Loss: 0.1243
# Epoch 49/200 - Train Loss: 0.0000, Val Loss: 0.1243
# Epoch 50/200 - Train Loss: 0.0000, Val Loss: 0.1244
# Epoch 51/200 - Train Loss: 0.0000, Val Loss: 0.1244
# Epoch 52/200 - Train Loss: 0.0000, Val Loss: 0.1245
# Epoch 53/200 - Train Loss: 0.0000, Val Loss: 0.1246
# Epoch 54/200 - Train Loss: 0.0000, Val Loss: 0.1246
# Epoch 55/200 - Train Loss: 0.0000, Val Loss: 0.1247
# Epoch 56/200 - Train Loss: 0.0000, Val Loss: 0.1247
# Epoch 57/200 - Train Loss: 0.0000, Val Loss: 0.1248
# Epoch 58/200 - Train Loss: 0.0000, Val Loss: 0.1248
# Epoch 59/200 - Train Loss: 0.0000, Val Loss: 0.1249
# Epoch 60/200 - Train Loss: 0.0000, Val Loss: 0.1249
# Epoch 61/200 - Train Loss: 0.0000, Val Loss: 0.1250
# Epoch 62/200 - Train Loss: 0.0000, Val Loss: 0.1250
# Epoch 63/200 - Train Loss: 0.0000, Val Loss: 0.1250
# Epoch 64/200 - Train Loss: 0.0000, Val Loss: 0.1251
# Epoch 65/200 - Train Loss: 0.0000, Val Loss: 0.1251
# Epoch 66/200 - Train Loss: 0.0000, Val Loss: 0.1252
# Epoch 67/200 - Train Loss: 0.0000, Val Loss: 0.1252
# Epoch 68/200 - Train Loss: 0.0000, Val Loss: 0.1253
# Epoch 69/200 - Train Loss: 0.0000, Val Loss: 0.1253
# Epoch 70/200 - Train Loss: 0.0000, Val Loss: 0.1253
# Epoch 71/200 - Train Loss: 0.0000, Val Loss: 0.1254
# Epoch 72/200 - Train Loss: 0.0000, Val Loss: 0.1255
# Epoch 73/200 - Train Loss: 0.0000, Val Loss: 0.1255
# Epoch 74/200 - Train Loss: 0.0000, Val Loss: 0.1255
# Epoch 75/200 - Train Loss: 0.0000, Val Loss: 0.1256
# Epoch 76/200 - Train Loss: 0.0000, Val Loss: 0.1256
# Epoch 77/200 - Train Loss: 0.0000, Val Loss: 0.1256
# Epoch 78/200 - Train Loss: 0.0000, Val Loss: 0.1257
# Epoch 79/200 - Train Loss: 0.0000, Val Loss: 0.1258
# Epoch 80/200 - Train Loss: 0.0000, Val Loss: 0.1258
# Epoch 81/200 - Train Loss: 0.0000, Val Loss: 0.1258
# Epoch 82/200 - Train Loss: 0.0000, Val Loss: 0.1259
# Epoch 83/200 - Train Loss: 0.0000, Val Loss: 0.1259
# Epoch 84/200 - Train Loss: 0.0000, Val Loss: 0.1260
# Epoch 85/200 - Train Loss: 0.0000, Val Loss: 0.1260
# Epoch 86/200 - Train Loss: 0.0000, Val Loss: 0.1261
# Epoch 87/200 - Train Loss: 0.0000, Val Loss: 0.1261
# Epoch 88/200 - Train Loss: 0.0000, Val Loss: 0.1261
# Epoch 89/200 - Train Loss: 0.0000, Val Loss: 0.1262
# Epoch 90/200 - Train Loss: 0.0000, Val Loss: 0.1262
# Epoch 91/200 - Train Loss: 0.0000, Val Loss: 0.1263
# Epoch 92/200 - Train Loss: 0.0000, Val Loss: 0.1263
# Epoch 93/200 - Train Loss: 0.0000, Val Loss: 0.1263
# Epoch 94/200 - Train Loss: 0.0000, Val Loss: 0.1264
# Epoch 95/200 - Train Loss: 0.0000, Val Loss: 0.1264
# Epoch 96/200 - Train Loss: 0.0000, Val Loss: 0.1264
# Epoch 97/200 - Train Loss: 0.0000, Val Loss: 0.1265
# Epoch 98/200 - Train Loss: 0.0000, Val Loss: 0.1266
# Epoch 99/200 - Train Loss: 0.0000, Val Loss: 0.1266
# Epoch 100/200 - Train Loss: 0.0000, Val Loss: 0.1266
# Epoch 101/200 - Train Loss: 0.0000, Val Loss: 0.1267
# Epoch 102/200 - Train Loss: 0.0000, Val Loss: 0.1267
# Epoch 103/200 - Train Loss: 0.0000, Val Loss: 0.1268
# Epoch 104/200 - Train Loss: 0.0000, Val Loss: 0.1268
# Epoch 105/200 - Train Loss: 0.0000, Val Loss: 0.1268
# Epoch 106/200 - Train Loss: 0.0000, Val Loss: 0.1268
# Epoch 107/200 - Train Loss: 0.0000, Val Loss: 0.1269
# Epoch 108/200 - Train Loss: 0.0000, Val Loss: 0.1269
# Epoch 109/200 - Train Loss: 0.0000, Val Loss: 0.1270
# Epoch 110/200 - Train Loss: 0.0000, Val Loss: 0.1271
# Epoch 111/200 - Train Loss: 0.0000, Val Loss: 0.1270
# Epoch 112/200 - Train Loss: 0.0000, Val Loss: 0.1271
# Epoch 113/200 - Train Loss: 0.0000, Val Loss: 0.1272
# Epoch 114/200 - Train Loss: 0.0000, Val Loss: 0.1272
# Epoch 115/200 - Train Loss: 0.0000, Val Loss: 0.1272
# Epoch 116/200 - Train Loss: 0.0000, Val Loss: 0.1273
# Epoch 117/200 - Train Loss: 0.0000, Val Loss: 0.1273
# Epoch 118/200 - Train Loss: 0.0000, Val Loss: 0.1273
# Epoch 119/200 - Train Loss: 0.0000, Val Loss: 0.1273
# Epoch 120/200 - Train Loss: 0.0000, Val Loss: 0.1274
# Epoch 121/200 - Train Loss: 0.0000, Val Loss: 0.1275
# Epoch 122/200 - Train Loss: 0.0000, Val Loss: 0.1275
# Epoch 123/200 - Train Loss: 0.0000, Val Loss: 0.1275
# Epoch 124/200 - Train Loss: 0.0000, Val Loss: 0.1275
# Epoch 125/200 - Train Loss: 0.0000, Val Loss: 0.1276
# Epoch 126/200 - Train Loss: 0.0000, Val Loss: 0.1276
# Epoch 127/200 - Train Loss: 0.0000, Val Loss: 0.1276
# Epoch 128/200 - Train Loss: 0.0000, Val Loss: 0.1277
# Epoch 129/200 - Train Loss: 0.0000, Val Loss: 0.1277
# Epoch 130/200 - Train Loss: 0.0000, Val Loss: 0.1278
# Epoch 131/200 - Train Loss: 0.0000, Val Loss: 0.1278
# Epoch 132/200 - Train Loss: 0.0000, Val Loss: 0.1278
# Epoch 133/200 - Train Loss: 0.0000, Val Loss: 0.1279
# Epoch 134/200 - Train Loss: 0.0000, Val Loss: 0.1279
# Epoch 135/200 - Train Loss: 0.0000, Val Loss: 0.1279
# Epoch 136/200 - Train Loss: 0.0000, Val Loss: 0.1280
# Epoch 137/200 - Train Loss: 0.0000, Val Loss: 0.1280
# Epoch 138/200 - Train Loss: 0.0000, Val Loss: 0.1281
# Epoch 139/200 - Train Loss: 0.0000, Val Loss: 0.1281
# Epoch 140/200 - Train Loss: 0.0000, Val Loss: 0.1281
# Epoch 141/200 - Train Loss: 0.0000, Val Loss: 0.1281
# Epoch 142/200 - Train Loss: 0.0000, Val Loss: 0.1282
# Epoch 143/200 - Train Loss: 0.0000, Val Loss: 0.1282
# Epoch 144/200 - Train Loss: 0.0000, Val Loss: 0.1283
# Epoch 145/200 - Train Loss: 0.0000, Val Loss: 0.1283
# Epoch 146/200 - Train Loss: 0.0000, Val Loss: 0.1283
# Epoch 147/200 - Train Loss: 0.0000, Val Loss: 0.1284
# Epoch 148/200 - Train Loss: 0.0000, Val Loss: 0.1284
# Epoch 149/200 - Train Loss: 0.0000, Val Loss: 0.1284
# Epoch 150/200 - Train Loss: 0.0000, Val Loss: 0.1284
# Epoch 151/200 - Train Loss: 0.0000, Val Loss: 0.1285
# Epoch 152/200 - Train Loss: 0.0000, Val Loss: 0.1285
# Epoch 153/200 - Train Loss: 0.0000, Val Loss: 0.1285
# Epoch 154/200 - Train Loss: 0.0000, Val Loss: 0.1286
# Epoch 155/200 - Train Loss: 0.0000, Val Loss: 0.1286
# Epoch 156/200 - Train Loss: 0.0000, Val Loss: 0.1286
# Epoch 157/200 - Train Loss: 0.0000, Val Loss: 0.1287
# Epoch 158/200 - Train Loss: 0.0000, Val Loss: 0.1287
# Epoch 159/200 - Train Loss: 0.0000, Val Loss: 0.1288
# Epoch 160/200 - Train Loss: 0.0000, Val Loss: 0.1288
# Epoch 161/200 - Train Loss: 0.0000, Val Loss: 0.1288
# Epoch 162/200 - Train Loss: 0.0000, Val Loss: 0.1288
# Epoch 163/200 - Train Loss: 0.0000, Val Loss: 0.1289
# Epoch 164/200 - Train Loss: 0.0000, Val Loss: 0.1289
# Epoch 165/200 - Train Loss: 0.0000, Val Loss: 0.1289
# Epoch 166/200 - Train Loss: 0.0000, Val Loss: 0.1290
# Epoch 167/200 - Train Loss: 0.0000, Val Loss: 0.1290
# Epoch 168/200 - Train Loss: 0.0000, Val Loss: 0.1290
# Epoch 169/200 - Train Loss: 0.0000, Val Loss: 0.1291
# Epoch 170/200 - Train Loss: 0.0000, Val Loss: 0.1291
# Epoch 171/200 - Train Loss: 0.0000, Val Loss: 0.1291
# Epoch 172/200 - Train Loss: 0.0000, Val Loss: 0.1291
# Epoch 173/200 - Train Loss: 0.0000, Val Loss: 0.1292
# Epoch 174/200 - Train Loss: 0.0000, Val Loss: 0.1292
# Epoch 175/200 - Train Loss: 0.0000, Val Loss: 0.1293
# Epoch 176/200 - Train Loss: 0.0000, Val Loss: 0.1293
# Epoch 177/200 - Train Loss: 0.0000, Val Loss: 0.1293
# Epoch 178/200 - Train Loss: 0.0000, Val Loss: 0.1294
# Epoch 179/200 - Train Loss: 0.0000, Val Loss: 0.1294
# Epoch 180/200 - Train Loss: 0.0000, Val Loss: 0.1295
# Epoch 181/200 - Train Loss: 0.0000, Val Loss: 0.1294
# Epoch 182/200 - Train Loss: 0.0000, Val Loss: 0.1295
# Epoch 183/200 - Train Loss: 0.0000, Val Loss: 0.1295
# Epoch 184/200 - Train Loss: 0.0000, Val Loss: 0.1295
# Epoch 185/200 - Train Loss: 0.0000, Val Loss: 0.1296
# Epoch 186/200 - Train Loss: 0.0000, Val Loss: 0.1296
# Epoch 187/200 - Train Loss: 0.0000, Val Loss: 0.1296
# Epoch 188/200 - Train Loss: 0.0000, Val Loss: 0.1296
# Epoch 189/200 - Train Loss: 0.0000, Val Loss: 0.1297
# Epoch 190/200 - Train Loss: 0.0000, Val Loss: 0.1297
# Epoch 191/200 - Train Loss: 0.0000, Val Loss: 0.1298
# Epoch 192/200 - Train Loss: 0.0000, Val Loss: 0.1298
# Epoch 193/200 - Train Loss: 0.0000, Val Loss: 0.1298
# Epoch 194/200 - Train Loss: 0.0000, Val Loss: 0.1298
# Epoch 195/200 - Train Loss: 0.0000, Val Loss: 0.1299
# Epoch 196/200 - Train Loss: 0.0000, Val Loss: 0.1299
# Epoch 197/200 - Train Loss: 0.0000, Val Loss: 0.1299
# Epoch 198/200 - Train Loss: 0.0000, Val Loss: 0.1300
# Epoch 199/200 - Train Loss: 0.0000, Val Loss: 0.1300
# Epoch 200/200 - Train Loss: 0.0000, Val Loss: 0.1300
# Epochs 200: Test Accuracy: 98.03%
#
# Best Epoch Configuration:
# Epochs: 20
# Test Accuracy: 98.06%
