# %%
import numpy as np 
import struct
from array import array
import os
import random
import matplotlib.pyplot as plt
from mlp import MultilayerPerceptron, Layer, CrossEntropy, Relu, Softmax

# -------------------- MNIST Data Loader Class -------------------- #

class MnistDataloader(object):
    """
    A class to load and preprocess the MNIST dataset from IDX files.
    """
    def __init__(self, training_images_filepath, training_labels_filepath,
                 test_images_filepath, test_labels_filepath):
        self.training_images_filepath = training_images_filepath
        self.training_labels_filepath = training_labels_filepath
        self.test_images_filepath = test_images_filepath
        self.test_labels_filepath = test_labels_filepath
    
    def read_images_labels(self, images_filepath, labels_filepath):        
        """
        Reads image and label data from IDX files.
        """
        # Read labels
        labels = []
        with open(labels_filepath, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))  # Read magic number and size
            if magic != 2049:
                raise ValueError(f'Magic number mismatch, expected 2049, got {magic}')
            labels = array("B", file.read())        
        
        # Read images
        with open(images_filepath, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))  # Read metadata
            if magic != 2051:
                raise ValueError(f'Magic number mismatch, expected 2051, got {magic}')
            image_data = array("B", file.read())  # Read pixel data        
        
        # Reshape image data into (size, 28, 28)
        images = [np.array(image_data[i * rows * cols:(i + 1) * rows * cols]).reshape(28, 28) for i in range(size)]
        
        return images, labels
            
    def load_data(self):
        """
        Loads training and test datasets.
        """
        x_train, y_train = self.read_images_labels(self.training_images_filepath, self.training_labels_filepath)
        x_test, y_test = self.read_images_labels(self.test_images_filepath, self.test_labels_filepath)
        return (x_train, y_train), (x_test, y_test)  

# -------------------- Reading Dataset via MnistDataloader class -------------------- #

data_folder = 'MNIST-data/'  # Dataset directory

# File paths for MNIST dataset
training_images_filepath = os.path.join(data_folder, 'train-images.idx3-ubyte')
training_labels_filepath = os.path.join(data_folder, 'train-labels.idx1-ubyte')
test_images_filepath = os.path.join(data_folder, 't10k-images.idx3-ubyte')
test_labels_filepath = os.path.join(data_folder, 't10k-labels.idx1-ubyte')

# Loading MNIST dataset
mnist_dataloader = MnistDataloader(training_images_filepath, training_labels_filepath, test_images_filepath, test_labels_filepath)
(x_train, y_train), (x_test, y_test) = mnist_dataloader.load_data()

# Converting lists to NumPy arrays and normalize pixel values
x_train = np.array(x_train).reshape(-1, 784) / 255.0  # Normalize & flatten
x_test = np.array(x_test).reshape(-1, 784) / 255.0
y_train = np.array(y_train)
y_test = np.array(y_test)

# Manual Train-Validation Split (80% train, 20% validation)
split_idx = int(len(x_train) * 0.8)
x_train, x_val = x_train[:split_idx], x_train[split_idx:]
y_train, y_val = y_train[:split_idx], y_train[split_idx:]

# Function to one-hot encode labels
def one_hot_encode(labels, num_classes=10):
    one_hot = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        one_hot[i][label] = 1
    return one_hot

# Converting labels to one-hot encoding
y_train = one_hot_encode(y_train)
y_val = one_hot_encode(y_val)
y_test = one_hot_encode(y_test)

# Function to display sample images
def show_images(images, title_texts):
    cols = 5
    rows = int(len(images) / cols) + 1
    plt.figure(figsize=(30, 20))
    index = 1
    for img, title in zip(images, title_texts):
        plt.subplot(rows, cols, index)
        plt.imshow(img, cmap=plt.cm.gray)
        plt.title(title, fontsize=15)
        index += 1

# -------------------- MLP Architecture for MNIST Dataset -------------------- #

# Define different momentum values to test
momentum_values = [0.0, 0.5, 0.7, 0.9, 0.99]

# Fixed layer architecture for comparison
fixed_layers = [
    Layer(784, 128, Relu(), dropout_rate=0.0),
    Layer(128, 128, Relu(), dropout_rate=0.0),
    Layer(128, 10, Softmax())
]

# Store results of test accuracies
results = {}

# Loop through different momentum values
for idx, momentum in enumerate(momentum_values):
    print(f"\nTraining with Momentum: {momentum}")

    # Define the MLP model with fixed layers
    mlp = MultilayerPerceptron(fixed_layers)

    # Define loss function
    loss_function = CrossEntropy()

    # Train the model
    train_losses, val_losses = mlp.train(
        x_train, y_train, x_val, y_val,
        loss_function, learning_rate=0.001,  # Keeping learning rate constant
        batch_size=64, epochs=50, optimizer='vanilla', momentum=momentum
    )

    # Evaluating model on test set
    y_pred = mlp.forward(x_test)
    test_accuracy = np.mean(np.argmax(y_pred, axis=1) == np.argmax(y_test, axis=1))

    # Store the result
    results[idx] = {
        "momentum": momentum,
        "test_accuracy": test_accuracy
    }

    print(f"Momentum {momentum}: Test Accuracy: {test_accuracy * 100:.2f}%")

# Find the best momentum value based on test accuracy
best_momentum_idx = max(results, key=lambda x: results[x]["test_accuracy"])
best_momentum = results[best_momentum_idx]

print("\nBest Momentum Configuration:")
print(f"Momentum: {best_momentum['momentum']}")
print(f"Test Accuracy: {best_momentum['test_accuracy'] * 100:.2f}%")
# Out:
# Training with Momentum: 0.0
# Epoch 1/50 - Train Loss: 0.4544, Val Loss: 0.2458
# Epoch 2/50 - Train Loss: 0.2162, Val Loss: 0.1870
# Epoch 3/50 - Train Loss: 0.1571, Val Loss: 0.1426
# Epoch 4/50 - Train Loss: 0.1241, Val Loss: 0.1268
# Epoch 5/50 - Train Loss: 0.1029, Val Loss: 0.1213
# Epoch 6/50 - Train Loss: 0.0869, Val Loss: 0.1032
# Epoch 7/50 - Train Loss: 0.0740, Val Loss: 0.0989
# Epoch 8/50 - Train Loss: 0.0646, Val Loss: 0.0968
# Epoch 9/50 - Train Loss: 0.0567, Val Loss: 0.0891
# Epoch 10/50 - Train Loss: 0.0496, Val Loss: 0.0865
# Epoch 11/50 - Train Loss: 0.0440, Val Loss: 0.0897
# Epoch 12/50 - Train Loss: 0.0388, Val Loss: 0.0844
# Epoch 13/50 - Train Loss: 0.0337, Val Loss: 0.0866
# Epoch 14/50 - Train Loss: 0.0304, Val Loss: 0.0839
# Epoch 15/50 - Train Loss: 0.0269, Val Loss: 0.0834
# Epoch 16/50 - Train Loss: 0.0231, Val Loss: 0.0843
# Epoch 17/50 - Train Loss: 0.0210, Val Loss: 0.0868
# Epoch 18/50 - Train Loss: 0.0186, Val Loss: 0.0835
# Epoch 19/50 - Train Loss: 0.0156, Val Loss: 0.0872
# Epoch 20/50 - Train Loss: 0.0142, Val Loss: 0.0843
# Epoch 21/50 - Train Loss: 0.0122, Val Loss: 0.0899
# Epoch 22/50 - Train Loss: 0.0110, Val Loss: 0.0857
# Epoch 23/50 - Train Loss: 0.0095, Val Loss: 0.0877
# Epoch 24/50 - Train Loss: 0.0084, Val Loss: 0.0861
# Epoch 25/50 - Train Loss: 0.0075, Val Loss: 0.0892
# Epoch 26/50 - Train Loss: 0.0066, Val Loss: 0.0891
# Epoch 27/50 - Train Loss: 0.0059, Val Loss: 0.0922
# Epoch 28/50 - Train Loss: 0.0053, Val Loss: 0.0910
# Epoch 29/50 - Train Loss: 0.0049, Val Loss: 0.0914
# Epoch 30/50 - Train Loss: 0.0045, Val Loss: 0.0908
# Epoch 31/50 - Train Loss: 0.0039, Val Loss: 0.0910
# Epoch 32/50 - Train Loss: 0.0036, Val Loss: 0.0921
# Epoch 33/50 - Train Loss: 0.0033, Val Loss: 0.0918
# Epoch 34/50 - Train Loss: 0.0030, Val Loss: 0.0917
# Epoch 35/50 - Train Loss: 0.0028, Val Loss: 0.0930
# Epoch 36/50 - Train Loss: 0.0026, Val Loss: 0.0938
# Epoch 37/50 - Train Loss: 0.0025, Val Loss: 0.0943
# Epoch 38/50 - Train Loss: 0.0023, Val Loss: 0.0946
# Epoch 39/50 - Train Loss: 0.0022, Val Loss: 0.0952
# Epoch 40/50 - Train Loss: 0.0021, Val Loss: 0.0962
# Epoch 41/50 - Train Loss: 0.0019, Val Loss: 0.0961
# Epoch 42/50 - Train Loss: 0.0019, Val Loss: 0.0966
# Epoch 43/50 - Train Loss: 0.0018, Val Loss: 0.0972
# Epoch 44/50 - Train Loss: 0.0017, Val Loss: 0.0974
# Epoch 45/50 - Train Loss: 0.0016, Val Loss: 0.0978
# Epoch 46/50 - Train Loss: 0.0015, Val Loss: 0.0980
# Epoch 47/50 - Train Loss: 0.0015, Val Loss: 0.0990
# Epoch 48/50 - Train Loss: 0.0014, Val Loss: 0.0986
# Epoch 49/50 - Train Loss: 0.0014, Val Loss: 0.0986
# Epoch 50/50 - Train Loss: 0.0013, Val Loss: 0.0998
# Momentum 0.0: Test Accuracy: 97.92%
#
# Training with Momentum: 0.5
# Epoch 1/50 - Train Loss: 0.0065, Val Loss: 0.1196
# Epoch 2/50 - Train Loss: 0.0309, Val Loss: 0.1247
# Epoch 3/50 - Train Loss: 0.0249, Val Loss: 0.1144
# Epoch 4/50 - Train Loss: 0.0113, Val Loss: 0.1241
# Epoch 5/50 - Train Loss: 0.0087, Val Loss: 0.1066
# Epoch 6/50 - Train Loss: 0.0042, Val Loss: 0.1015
# Epoch 7/50 - Train Loss: 0.0019, Val Loss: 0.1023
# Epoch 8/50 - Train Loss: 0.0008, Val Loss: 0.1023
# Epoch 9/50 - Train Loss: 0.0007, Val Loss: 0.1023
# Epoch 10/50 - Train Loss: 0.0006, Val Loss: 0.1036
# Epoch 11/50 - Train Loss: 0.0006, Val Loss: 0.1045
# Epoch 12/50 - Train Loss: 0.0005, Val Loss: 0.1043
# Epoch 13/50 - Train Loss: 0.0005, Val Loss: 0.1046
# Epoch 14/50 - Train Loss: 0.0005, Val Loss: 0.1048
# Epoch 15/50 - Train Loss: 0.0004, Val Loss: 0.1053
# Epoch 16/50 - Train Loss: 0.0004, Val Loss: 0.1058
# Epoch 17/50 - Train Loss: 0.0004, Val Loss: 0.1056
# Epoch 18/50 - Train Loss: 0.0004, Val Loss: 0.1061
# Epoch 19/50 - Train Loss: 0.0004, Val Loss: 0.1062
# Epoch 20/50 - Train Loss: 0.0003, Val Loss: 0.1077
# Epoch 21/50 - Train Loss: 0.0003, Val Loss: 0.1072
# Epoch 22/50 - Train Loss: 0.0003, Val Loss: 0.1075
# Epoch 23/50 - Train Loss: 0.0003, Val Loss: 0.1080
# Epoch 24/50 - Train Loss: 0.0003, Val Loss: 0.1079
# Epoch 25/50 - Train Loss: 0.0003, Val Loss: 0.1084
# Epoch 26/50 - Train Loss: 0.0003, Val Loss: 0.1088
# Epoch 27/50 - Train Loss: 0.0003, Val Loss: 0.1091
# Epoch 28/50 - Train Loss: 0.0003, Val Loss: 0.1089
# Epoch 29/50 - Train Loss: 0.0003, Val Loss: 0.1099
# Epoch 30/50 - Train Loss: 0.0002, Val Loss: 0.1098
# Epoch 31/50 - Train Loss: 0.0002, Val Loss: 0.1102
# Epoch 32/50 - Train Loss: 0.0002, Val Loss: 0.1104
# Epoch 33/50 - Train Loss: 0.0002, Val Loss: 0.1104
# Epoch 34/50 - Train Loss: 0.0002, Val Loss: 0.1106
# Epoch 35/50 - Train Loss: 0.0002, Val Loss: 0.1111
# Epoch 36/50 - Train Loss: 0.0002, Val Loss: 0.1108
# Epoch 37/50 - Train Loss: 0.0002, Val Loss: 0.1113
# Epoch 38/50 - Train Loss: 0.0002, Val Loss: 0.1114
# Epoch 39/50 - Train Loss: 0.0002, Val Loss: 0.1117
# Epoch 40/50 - Train Loss: 0.0002, Val Loss: 0.1120
# Epoch 41/50 - Train Loss: 0.0002, Val Loss: 0.1123
# Epoch 42/50 - Train Loss: 0.0002, Val Loss: 0.1122
# Epoch 43/50 - Train Loss: 0.0002, Val Loss: 0.1121
# Epoch 44/50 - Train Loss: 0.0002, Val Loss: 0.1128
# Epoch 45/50 - Train Loss: 0.0002, Val Loss: 0.1125
# Epoch 46/50 - Train Loss: 0.0002, Val Loss: 0.1132
# Epoch 47/50 - Train Loss: 0.0002, Val Loss: 0.1127
# Epoch 48/50 - Train Loss: 0.0002, Val Loss: 0.1130
# Epoch 49/50 - Train Loss: 0.0002, Val Loss: 0.1135
# Epoch 50/50 - Train Loss: 0.0002, Val Loss: 0.1137
# Momentum 0.5: Test Accuracy: 98.03%
#
# Training with Momentum: 0.7
# Epoch 1/50 - Train Loss: 0.0002, Val Loss: 0.1141
# Epoch 2/50 - Train Loss: 0.0002, Val Loss: 0.1143
# Epoch 3/50 - Train Loss: 0.0002, Val Loss: 0.1145
# Epoch 4/50 - Train Loss: 0.0001, Val Loss: 0.1142
# Epoch 5/50 - Train Loss: 0.0001, Val Loss: 0.1150
# Epoch 6/50 - Train Loss: 0.0001, Val Loss: 0.1148
# Epoch 7/50 - Train Loss: 0.0001, Val Loss: 0.1154
# Epoch 8/50 - Train Loss: 0.0001, Val Loss: 0.1156
# Epoch 9/50 - Train Loss: 0.0001, Val Loss: 0.1164
# Epoch 10/50 - Train Loss: 0.0001, Val Loss: 0.1157
# Epoch 11/50 - Train Loss: 0.0001, Val Loss: 0.1163
# Epoch 12/50 - Train Loss: 0.0001, Val Loss: 0.1164
# Epoch 13/50 - Train Loss: 0.0001, Val Loss: 0.1162
# Epoch 14/50 - Train Loss: 0.0001, Val Loss: 0.1164
# Epoch 15/50 - Train Loss: 0.0001, Val Loss: 0.1168
# Epoch 16/50 - Train Loss: 0.0001, Val Loss: 0.1171
# Epoch 17/50 - Train Loss: 0.0001, Val Loss: 0.1174
# Epoch 18/50 - Train Loss: 0.0001, Val Loss: 0.1177
# Epoch 19/50 - Train Loss: 0.0001, Val Loss: 0.1179
# Epoch 20/50 - Train Loss: 0.0001, Val Loss: 0.1182
# Epoch 21/50 - Train Loss: 0.0001, Val Loss: 0.1180
# Epoch 22/50 - Train Loss: 0.0001, Val Loss: 0.1182
# Epoch 23/50 - Train Loss: 0.0001, Val Loss: 0.1186
# Epoch 24/50 - Train Loss: 0.0001, Val Loss: 0.1185
# Epoch 25/50 - Train Loss: 0.0001, Val Loss: 0.1189
# Epoch 26/50 - Train Loss: 0.0001, Val Loss: 0.1193
# Epoch 27/50 - Train Loss: 0.0001, Val Loss: 0.1190
# Epoch 28/50 - Train Loss: 0.0001, Val Loss: 0.1195
# Epoch 29/50 - Train Loss: 0.0001, Val Loss: 0.1196
# Epoch 30/50 - Train Loss: 0.0001, Val Loss: 0.1197
# Epoch 31/50 - Train Loss: 0.0001, Val Loss: 0.1199
# Epoch 32/50 - Train Loss: 0.0001, Val Loss: 0.1197
# Epoch 33/50 - Train Loss: 0.0001, Val Loss: 0.1201
# Epoch 34/50 - Train Loss: 0.0001, Val Loss: 0.1203
# Epoch 35/50 - Train Loss: 0.0001, Val Loss: 0.1206
# Epoch 36/50 - Train Loss: 0.0001, Val Loss: 0.1206
# Epoch 37/50 - Train Loss: 0.0001, Val Loss: 0.1208
# Epoch 38/50 - Train Loss: 0.0001, Val Loss: 0.1209
# Epoch 39/50 - Train Loss: 0.0001, Val Loss: 0.1212
# Epoch 40/50 - Train Loss: 0.0001, Val Loss: 0.1214
# Epoch 41/50 - Train Loss: 0.0001, Val Loss: 0.1214
# Epoch 42/50 - Train Loss: 0.0001, Val Loss: 0.1213
# Epoch 43/50 - Train Loss: 0.0001, Val Loss: 0.1215
# Epoch 44/50 - Train Loss: 0.0001, Val Loss: 0.1217
# Epoch 45/50 - Train Loss: 0.0001, Val Loss: 0.1219
# Epoch 46/50 - Train Loss: 0.0001, Val Loss: 0.1220
# Epoch 47/50 - Train Loss: 0.0001, Val Loss: 0.1222
# Epoch 48/50 - Train Loss: 0.0001, Val Loss: 0.1223
# Epoch 49/50 - Train Loss: 0.0001, Val Loss: 0.1223
# Epoch 50/50 - Train Loss: 0.0001, Val Loss: 0.1222
# Momentum 0.7: Test Accuracy: 98.07%
#
# Training with Momentum: 0.9
# Epoch 1/50 - Train Loss: 0.0001, Val Loss: 0.1230
# Epoch 2/50 - Train Loss: 0.0001, Val Loss: 0.1232
# Epoch 3/50 - Train Loss: 0.0001, Val Loss: 0.1238
# Epoch 4/50 - Train Loss: 0.0001, Val Loss: 0.1241
# Epoch 5/50 - Train Loss: 0.0001, Val Loss: 0.1240
# Epoch 6/50 - Train Loss: 0.0001, Val Loss: 0.1241
# Epoch 7/50 - Train Loss: 0.0001, Val Loss: 0.1250
# Epoch 8/50 - Train Loss: 0.0001, Val Loss: 0.1249
# Epoch 9/50 - Train Loss: 0.0001, Val Loss: 0.1248
# Epoch 10/50 - Train Loss: 0.0000, Val Loss: 0.1257
# Epoch 11/50 - Train Loss: 0.0000, Val Loss: 0.1257
# Epoch 12/50 - Train Loss: 0.0000, Val Loss: 0.1256
# Epoch 13/50 - Train Loss: 0.0000, Val Loss: 0.1264
# Epoch 14/50 - Train Loss: 0.0000, Val Loss: 0.1268
# Epoch 15/50 - Train Loss: 0.0000, Val Loss: 0.1271
# Epoch 16/50 - Train Loss: 0.0000, Val Loss: 0.1271
# Epoch 17/50 - Train Loss: 0.0000, Val Loss: 0.1275
# Epoch 18/50 - Train Loss: 0.0000, Val Loss: 0.1277
# Epoch 19/50 - Train Loss: 0.0000, Val Loss: 0.1278
# Epoch 20/50 - Train Loss: 0.0000, Val Loss: 0.1276
# Epoch 21/50 - Train Loss: 0.0000, Val Loss: 0.1282
# Epoch 22/50 - Train Loss: 0.0000, Val Loss: 0.1286
# Epoch 23/50 - Train Loss: 0.0000, Val Loss: 0.1283
# Epoch 24/50 - Train Loss: 0.0000, Val Loss: 0.1288
# Epoch 25/50 - Train Loss: 0.0000, Val Loss: 0.1291
# Epoch 26/50 - Train Loss: 0.0000, Val Loss: 0.1293
# Epoch 27/50 - Train Loss: 0.0000, Val Loss: 0.1294
# Epoch 28/50 - Train Loss: 0.0000, Val Loss: 0.1297
# Epoch 29/50 - Train Loss: 0.0000, Val Loss: 0.1298
# Epoch 30/50 - Train Loss: 0.0000, Val Loss: 0.1299
# Epoch 31/50 - Train Loss: 0.0000, Val Loss: 0.1299
# Epoch 32/50 - Train Loss: 0.0000, Val Loss: 0.1301
# Epoch 33/50 - Train Loss: 0.0000, Val Loss: 0.1306
# Epoch 34/50 - Train Loss: 0.0000, Val Loss: 0.1306
# Epoch 35/50 - Train Loss: 0.0000, Val Loss: 0.1310
# Epoch 36/50 - Train Loss: 0.0000, Val Loss: 0.1307
# Epoch 37/50 - Train Loss: 0.0000, Val Loss: 0.1309
# Epoch 38/50 - Train Loss: 0.0000, Val Loss: 0.1312
# Epoch 39/50 - Train Loss: 0.0000, Val Loss: 0.1316
# Epoch 40/50 - Train Loss: 0.0000, Val Loss: 0.1314
# Epoch 41/50 - Train Loss: 0.0000, Val Loss: 0.1317
# Epoch 42/50 - Train Loss: 0.0000, Val Loss: 0.1320
# Epoch 43/50 - Train Loss: 0.0000, Val Loss: 0.1319
# Epoch 44/50 - Train Loss: 0.0000, Val Loss: 0.1320
# Epoch 45/50 - Train Loss: 0.0000, Val Loss: 0.1322
# Epoch 46/50 - Train Loss: 0.0000, Val Loss: 0.1326
# Epoch 47/50 - Train Loss: 0.0000, Val Loss: 0.1325
# Epoch 48/50 - Train Loss: 0.0000, Val Loss: 0.1325
# Epoch 49/50 - Train Loss: 0.0000, Val Loss: 0.1328
# Epoch 50/50 - Train Loss: 0.0000, Val Loss: 0.1330
# Momentum 0.9: Test Accuracy: 98.06%
#
# Training with Momentum: 0.99
# Epoch 1/50 - Train Loss: 0.7738, Val Loss: 2.3820
# Epoch 2/50 - Train Loss: 2.3256, Val Loss: 2.3174
# Epoch 3/50 - Train Loss: 2.3173, Val Loss: 2.3131
# Epoch 4/50 - Train Loss: 2.3256, Val Loss: 2.3499
# Epoch 5/50 - Train Loss: 2.3220, Val Loss: 2.3275
# Epoch 6/50 - Train Loss: 2.3274, Val Loss: 2.3372
# Epoch 7/50 - Train Loss: 2.3180, Val Loss: 2.3243
# Epoch 8/50 - Train Loss: 2.3238, Val Loss: 2.3258
# Epoch 9/50 - Train Loss: 2.3231, Val Loss: 2.3163
# Epoch 10/50 - Train Loss: 2.3213, Val Loss: 2.3161
# Epoch 11/50 - Train Loss: 2.3207, Val Loss: 2.3195
# Epoch 12/50 - Train Loss: 2.3187, Val Loss: 2.3135
# Epoch 13/50 - Train Loss: 2.3207, Val Loss: 2.3098
# Epoch 14/50 - Train Loss: 2.3289, Val Loss: 2.3286
# Epoch 15/50 - Train Loss: 2.3221, Val Loss: 2.3286
# Epoch 16/50 - Train Loss: 2.3198, Val Loss: 2.3103
# Epoch 17/50 - Train Loss: 2.3219, Val Loss: 2.3120
# Epoch 18/50 - Train Loss: 2.3187, Val Loss: 2.3252
# Epoch 19/50 - Train Loss: 2.3208, Val Loss: 2.3288
# Epoch 20/50 - Train Loss: 2.3262, Val Loss: 2.3325
# Epoch 21/50 - Train Loss: 2.3234, Val Loss: 2.3132
# Epoch 22/50 - Train Loss: 2.3185, Val Loss: 2.3296
# Epoch 23/50 - Train Loss: 2.3327, Val Loss: 2.3185
# Epoch 24/50 - Train Loss: 2.3209, Val Loss: 2.3206
# Epoch 25/50 - Train Loss: 2.3212, Val Loss: 2.3088
# Epoch 26/50 - Train Loss: 2.3199, Val Loss: 2.3540
# Epoch 27/50 - Train Loss: 2.3254, Val Loss: 2.3246
# Epoch 28/50 - Train Loss: 2.3184, Val Loss: 2.3290
# Epoch 29/50 - Train Loss: 2.3245, Val Loss: 2.3308
# Epoch 30/50 - Train Loss: 2.3326, Val Loss: 2.3263
# Epoch 31/50 - Train Loss: 2.3199, Val Loss: 2.3281
# Epoch 32/50 - Train Loss: 2.3246, Val Loss: 2.3338
# Epoch 33/50 - Train Loss: 2.3204, Val Loss: 2.3465
# Epoch 34/50 - Train Loss: 2.3240, Val Loss: 2.3240
# Epoch 35/50 - Train Loss: 2.3190, Val Loss: 2.3265
# Epoch 36/50 - Train Loss: 2.3176, Val Loss: 2.3181
# Epoch 37/50 - Train Loss: 2.3200, Val Loss: 2.3282
# Epoch 38/50 - Train Loss: 2.3209, Val Loss: 2.3234
# Epoch 39/50 - Train Loss: 2.3245, Val Loss: 2.3269
# Epoch 40/50 - Train Loss: 2.3226, Val Loss: 2.3265
# Epoch 41/50 - Train Loss: 2.3257, Val Loss: 2.3292
# Epoch 42/50 - Train Loss: 2.3314, Val Loss: 2.3604
# Epoch 43/50 - Train Loss: 2.3228, Val Loss: 2.3351
# Epoch 44/50 - Train Loss: 2.3183, Val Loss: 2.3193
# Epoch 45/50 - Train Loss: 2.3270, Val Loss: 2.3195
# Epoch 46/50 - Train Loss: 2.3256, Val Loss: 2.3343
# Epoch 47/50 - Train Loss: 2.3258, Val Loss: 2.3192
# Epoch 48/50 - Train Loss: 2.3250, Val Loss: 2.3343
# Epoch 49/50 - Train Loss: 2.3234, Val Loss: 2.3292
# Epoch 50/50 - Train Loss: 2.3221, Val Loss: 2.3234
# Momentum 0.99: Test Accuracy: 10.10%
#
# Best Momentum Configuration:
# Momentum: 0.7
# Test Accuracy: 98.07%
